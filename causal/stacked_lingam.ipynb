# %% [markdown]
# # Load and wrangle dataset

# %%
import pandas as pd, numpy as np

df = pd.read_csv("data/processed/phq4_ts_features.csv")

# keep rows that have SRI and at least 7 PHQ-4 observations
df = df.dropna(subset=["SRI"])
valid_pids = df["pid"].value_counts().loc[lambda s: s >= 7].index
df = df[df["pid"].isin(valid_pids)]

# drop very sparse columns (>1000 missing) & keep predictors only
missing = df.isna().sum()
keep_cols = missing[missing < 1000].index.difference(
    ["pid", "PHQ4_date", "PHQ4"]
)
# --- after you load & basic-filter df ---------------------------
df = df.sort_values(["pid", "PHQ4_date"])

# 1. create deviation-from-subject-mean
df["PHQ4_dev"] = df["PHQ4"] - df.groupby("pid")["PHQ4"].transform("mean")

# 2. keep core + Elastic-Net picks, but USE PHQ4_dev instead of PHQ4
circadian_core = ["PHQ4_dev", "SRI", "dlmo_proxy", "sigma_bed", "mid_sleep"]
enet_vars      = pd.read_csv("data/processed/selected_predictors.csv")["PHQ4_dev"]

vars_all = list(dict.fromkeys(circadian_core + enet_vars.tolist()))

vars_all = [v for v in vars_all if v != "PHQ4_dev"] + ["PHQ4_dev"]
p        = len(vars_all)

# %% [markdown]
# # z-score features

# %%
def zscore_subject(group: pd.DataFrame) -> pd.DataFrame:
    z = group[vars_all].copy()
    # z-score every column **except** PHQ4_dev
    for col in vars_all:
        if col == "PHQ4_dev":
            continue                   # leave raw deviation
        mu  = z[col].mean()
        sd  = z[col].std(ddof=0)
        z[col] = (z[col] - mu) / (sd if sd > 0 else 1.0)
    return z.fillna(0)                 # residual NaN → 0

df_z = (
    df.groupby("pid", sort=False)
      .apply(zscore_subject)
      .reset_index(level=0)            # keep pid as a column
)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_83373/827302596.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(zscore_subject)

# %% [markdown]
# # Stack datasets

# %%
T = 10                      # longest window you want to model
pids = df_z["pid"].unique()
N = len(pids)

X_t = np.zeros((T, N, p), dtype=np.float64)

for subj_idx, pid in enumerate(pids):
    seq = df_z.loc[df_z["pid"] == pid, vars_all].to_numpy()
    t_len = min(len(seq), T)
    X_t[:t_len, subj_idx, :] = seq[:t_len]      # left-align (earliest first)

# %% [markdown]
# # Try Lingam

# %%
from lingam import LongitudinalLiNGAM
model = LongitudinalLiNGAM(n_lags=2, random_state=0)
model.fit(X_t)
# Out:
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.152e-04, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.385e-05, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.053e-06, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=9.935e-04, with an active set of 11 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=4.216e-04, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=3.490e-05, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=6.326e-05, with an active set of 11 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=3.118e-05, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=6.131e-06, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.890e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.195e-06, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.890e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.203e-07, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.890e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=2.004e-07, with an active set of 11 regressors, and the smallest cholesky pivot element being 5.890e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=1.166e-05, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.634e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=3.046e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 6.452e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=2.235e-06, with an active set of 21 regressors, and the smallest cholesky pivot element being 6.452e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=5.310e-05, with an active set of 18 regressors, and the smallest cholesky pivot element being 6.969e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=1.826e-05, with an active set of 20 regressors, and the smallest cholesky pivot element being 6.969e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.574e-07, with an active set of 21 regressors, and the smallest cholesky pivot element being 6.969e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=4.010e-05, with an active set of 21 regressors, and the smallest cholesky pivot element being 1.290e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=3.242e-06, with an active set of 22 regressors, and the smallest cholesky pivot element being 1.290e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/sklearn/linear_model/_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=1.066e-06, with an active set of 22 regressors, and the smallest cholesky pivot element being 1.317e-09. Reduce max_iter or increase eps parameters.
#   warnings.warn(

# %% [markdown]
# # View graph and causal effects estimation

# %%
# -----------------------------------------------------------
# Visualise and inspect LongitudinalLiNGAM results
# -----------------------------------------------------------
from lingam.utils import make_dot
import graphviz, numpy as np, pandas as pd

# -- helper --------------------------------------------------
def edge_table(B, src_lab, tgt_lab, lag, thr=0.05):
    i, j = np.where(np.abs(B) > thr)
    return pd.DataFrame({
        "lag"   : lag,
        "from"  : [src_lab[a] for a in i],
        "to"    : [tgt_lab[b] for b in j],
        "weight": B[i, j].round(3)
    })

# -----------------------------------------------------------
# 1.  Instantaneous graph  B(t,t)   (last time-point)
# -----------------------------------------------------------
t_last   = X_t.shape[0] - 1
p        = len(vars_all)
labels_t = [f"{v}(t)" for v in vars_all]

B_inst   = model.adjacency_matrices_[t_last, 0]
dot_inst = make_dot(B_inst, labels=labels_t)
dot_inst.render("inst_graph", format="png", view=True)   # saves & opens PNG

# -----------------------------------------------------------
# 2.  Lag-1 graph  B(t,t-1)
#     (place edges in lower-left quadrant of a 2p×2p matrix)
# -----------------------------------------------------------
B_lag1   = model.adjacency_matrices_[t_last, 1]
B_big    = np.zeros((2*p, 2*p))
B_big[p:, :p] = B_lag1

labels_lag = [f"{v}(t-1)" for v in vars_all] + [f"{v}(t)" for v in vars_all]
dot_lag1   = make_dot(B_big, labels=labels_lag)
dot_lag1.render("lag1_graph", format="png", view=True)

# -----------------------------------------------------------
# 3.  Edge list (threshold |w| ≥ 0.05)
# -----------------------------------------------------------
edges0 = edge_table(B_inst, vars_all, vars_all, lag=0)
edges1 = edge_table(B_lag1,
                    [f"{v}(t-1)" for v in vars_all],
                    [f"{v}(t)"   for v in vars_all],
                    lag=1)
edges  = pd.concat([edges0, edges1], ignore_index=True)
print("\n=== Direct edges (|w| ≥ 0.05) ===")
print(edges.sort_values("weight", key=np.abs, ascending=False).to_string(index=False))

# -----------------------------------------------------------
# 4.  Quick total effect  SRI → PHQ4_dev  (same-time)
# -----------------------------------------------------------
from lingam import DirectLiNGAM
X_flat = X_t.reshape(-1, p)          # treat each (subject,time) row as i.i.d.
dlin   = DirectLiNGAM(random_state=0).fit(X_flat)

src = vars_all.index("SRI")
tgt = vars_all.index("PHQ4_dev")
tot = dlin.estimate_total_effect(X_flat, src, tgt)
print(f"\nTotal effect  SRI → PHQ4_dev  = {tot:.3f}")
# Out:
# === Direct edges (|w| ≥ 0.05) ===
#  lag                                                                                   from                                                                                   to  weight
#    0       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std    slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std   1.000
#    0        slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std   1.000
#    1                                                                          PHQ4_dev(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.868
#    1                                                                          PHQ4_dev(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.831
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.590
#    1            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.578
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.570
#    1        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.550
#    1            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.537
#    1        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.536
#    0                 steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std   0.503
#    1           slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.495
#    1           slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.486
#    1           slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.463
#    0                                                                               PHQ4_dev         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean   0.458
#    1           slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.456
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std                                                                            sigma_bed   0.433
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.411
#    1                                                                        dlmo_proxy(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.400
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.399
#    1                                                                        dlmo_proxy(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.368
#    0           slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope   0.349
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std             slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std   0.327
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std  -0.311
#    0                                                                              mid_sleep                                                                                  SRI  -0.308
#    1               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.303
#    1               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.293
#    0                                                                               PHQ4_dev         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope  -0.283
#    0                                                                              mid_sleep         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean   0.283
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.275
#    0         slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean   0.272
#    0                                                                               PHQ4_dev                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean  -0.270
#    0                    steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean   0.264
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.262
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.258
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.258
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std                                                                                  SRI   0.250
#    0                                                                              sigma_bed    slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std   0.248
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.247
#    1                                                                               SRI(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.247
#    0                                                                              sigma_bed             slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std   0.244
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope               steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std   0.234
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope                                                                                  SRI  -0.233
#    0                    steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean   0.233
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.231
#    0                                                                              sigma_bed                                                                                  SRI  -0.224
#    1                                                                               SRI(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.223
#    0                                                                                    SRI                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean  -0.223
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.214
#    0         slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope  -0.211
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope                                                                                  SRI  -0.202
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.202
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.201
#    1           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.200
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std                 steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope   0.193
#    0             screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std            steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope   0.193
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std  -0.189
#    0               slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean  -0.186
#    0                 steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std                  steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean  -0.185
#    0                                                                              mid_sleep              slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope  -0.184
#    1                                                                          PHQ4_dev(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.183
#    0                                                                              sigma_bed                 steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope  -0.183
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.175
#    0               slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std                                                                                  SRI  -0.170
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.169
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope  -0.169
#    0                                                                              mid_sleep                 steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope   0.169
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.167
#    1           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.167
#    0                                                                                    SRI       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std  -0.166
#    0                   steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean   0.165
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope   0.162
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.161
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std  -0.160
#    0                 steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean  -0.159
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope               steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope  -0.158
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.157
#    0                                                                             dlmo_proxy                                                                            sigma_bed  -0.157
#    1                                                                          PHQ4_dev(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)   0.154
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std     slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std   0.153
#    1                                                                          PHQ4_dev(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.152
#    0                 steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope               steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std   0.150
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.150
#    1               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.147
#    0                   steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope  -0.147
#    1                                                                         mid_sleep(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.146
#    0                                                                              mid_sleep               steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope   0.146
#    0                                                                             dlmo_proxy             slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std  -0.143
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.143
#    0                 steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope  -0.142
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.142
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std   0.139
#    1                                                                         mid_sleep(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.139
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.138
#    0             screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope  -0.138
#    0                                                                              mid_sleep         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope   0.137
#    0                                                                              sigma_bed         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope   0.137
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std                  steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean   0.136
#    0                 steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope  -0.136
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope   0.131
#    0           slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean                         slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean   0.131
#    1               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.131
#    1           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.127
#    0                 steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std  -0.125
#    0              steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope  -0.125
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std                                                                                  SRI   0.124
#    0                                                                             dlmo_proxy                  steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean  -0.119
#    0                   steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope                  steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std  -0.119
#    0                                                                                    SRI                  steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std  -0.116
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std         slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean  -0.116
#    0                                                                              mid_sleep               steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std  -0.115
#    0                                                                             dlmo_proxy                                                                            mid_sleep   0.115
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std   0.115
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.113
#    0                                                                             dlmo_proxy           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std   0.111
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.111
#    0                                                                              mid_sleep                  steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std   0.110
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope               steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std  -0.108
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std  -0.107
#    1    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t-1)                                                                         sigma_bed(t)   0.106
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.106
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std                                                                            mid_sleep  -0.105
#    1                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)  -0.102
#    0                                                                              sigma_bed              slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope  -0.102
#    1           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.101
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope         slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope   0.101
#    0                 steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope       slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std  -0.101
#    0           slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean               steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std   0.099
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope                  steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std  -0.099
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope            steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope  -0.098
#    0      slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std            steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope  -0.098
#    1    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)  -0.098
#    0                                                                              mid_sleep             slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std  -0.097
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.096
#    1      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.096
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std            steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope   0.093
#    0                slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope                                                                             PHQ4_dev   0.092
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.092
#    0                                                                             dlmo_proxy     slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std   0.091
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)   0.088
#    0                screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std         screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope  -0.087
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1)      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t)  -0.084
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t)   0.084
#    1            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)  -0.084
#    1      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t-1)      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t)  -0.083
#    1        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t-1)            steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std(t)  -0.082
#    1                                                                          PHQ4_dev(t-1)      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t)  -0.081
#    1                                                                          PHQ4_dev(t-1)                                                                        dlmo_proxy(t)   0.080
#    1            steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.077
#    1      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.077
#    1                                                                          PHQ4_dev(t-1)        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t)  -0.077
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.076
#    1                                                                          PHQ4_dev(t-1)               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t)   0.076
#    0                                                                             dlmo_proxy              slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope   0.075
#    1    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.073
#    1                                                                         sigma_bed(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.073
#    1    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.072
#    1  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.071
#    1           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t-1)           screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_allday_std(t)  -0.071
#    1  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.071
#    1      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.070
#    1        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)  -0.068
#    1      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)   0.066
#    1           slp_fitbit_sleep_summary_rapids_sumdurationafterwakeupmain_allday_slope(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)  -0.066
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t)   0.065
#    1            steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std(t-1)            steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std(t)  -0.064
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.064
#    1                                                                         mid_sleep(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.064
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)  -0.064
#    1               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.064
#    1                                                                          PHQ4_dev(t-1)                                                                         sigma_bed(t)  -0.064
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t)  -0.063
#    1                                                                         sigma_bed(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.063
#    1        screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std(t-1)      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t)  -0.063
#    1                                                                               SRI(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)  -0.063
#    1      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)  -0.062
#    1      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t-1)      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t)  -0.061
#    1            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.061
#    1      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)   0.061
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t)  -0.060
#    1      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)  -0.059
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t)  -0.059
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1)                      slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean(t)   0.059
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)      screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_slope(t)   0.058
#    0                                                                              mid_sleep                                                                             PHQ4_dev   0.058
#    1                                                                        dlmo_proxy(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.058
#    1                                                                               SRI(t-1) slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t)   0.057
#    1                                                                          PHQ4_dev(t-1)            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t)  -0.057
#    1                                                                         mid_sleep(t-1)    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t)   0.057
#    1      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t-1)   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std(t)  -0.057
#    1            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t-1)               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t)   0.056
#    1                                                                          PHQ4_dev(t-1)                                                                          PHQ4_dev(t)   0.055
#    1              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t-1)      slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope(t)  -0.055
#    1 slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std(t-1)  slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std(t)   0.053
#    1            steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope(t-1)         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t)   0.053
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)  -0.053
#    1                                                                        dlmo_proxy(t-1)      slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean(t)   0.052
#    1          slp_fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain_evening_std(t-1)            steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std(t)  -0.052
#    1                                                                         sigma_bed(t-1)               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t)   0.052
#    1    slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std(t-1)               steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean(t)   0.052
#    1                                                                               SRI(t-1)               steps_fitbit_steps_intraday_rapids_countepisodeactivebout_night_std(t)  -0.052
#    1                                                                          PHQ4_dev(t-1)                                                                               SRI(t)  -0.051
#    1                                                                          PHQ4_dev(t-1)              steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope(t)  -0.051
#    1         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t-1)         steps_fitbit_steps_intraday_rapids_stddurationsedentarybout_morning_slope(t)  -0.051
#
# Total effect  SRI → PHQ4_dev  = -0.020
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=0).
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from lingam import DirectLiNGAM

# 1️⃣ Identify direct parents of PHQ4_dev at t = last
t_last = X_t.shape[0] - 1
p      = len(vars_all)
target = vars_all.index("PHQ4_dev")
thr    = 0.05

parents = []
# model.adjacency_matrices_[t, lag] has shape (p,p)
for lag in range(model.adjacency_matrices_.shape[1]):
    B = model.adjacency_matrices_[t_last, lag]
    idx = np.where(np.abs(B[target, :]) > thr)[0]
    for i in idx:
        parents.append((vars_all[i], lag))
# unique
parents = list(dict.fromkeys(parents))
print(len(parents))
print("Direct parents of PHQ4_dev (var, lag):")
for parent in parents:
    print(f"  {parent[0]} (lag {parent[1]})")
# Out:
# 29
# Direct parents of PHQ4_dev (var, lag):
#   slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope (lag 0)
#   slp_fitbit_sleep_summary_rapids_countepisodemain_allday_mean (lag 0)
#   slp_fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain_afternoon_mean (lag 0)
#   SRI (lag 1)
#   dlmo_proxy (lag 1)
#   sigma_bed (lag 1)
#   slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope (lag 1)
#   steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std (lag 1)
#   steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean (lag 1)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std (lag 1)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std (lag 1)
#   steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope (lag 1)
#   screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std (lag 1)
#   steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope (lag 1)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std (lag 1)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std (lag 1)
#   PHQ4_dev (lag 1)
#   SRI (lag 2)
#   slp_fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain_afternoon_slope (lag 2)
#   steps_fitbit_steps_intraday_rapids_mindurationsedentarybout_allday_std (lag 2)
#   steps_fitbit_steps_intraday_rapids_mindurationactivebout_night_mean (lag 2)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_night_std (lag 2)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_night_std (lag 2)
#   steps_fitbit_steps_intraday_rapids_avgdurationsedentarybout_allday_std (lag 2)
#   steps_fitbit_steps_intraday_rapids_avgdurationactivebout_night_slope (lag 2)
#   screen_phone_screen_rapids_firstuseafter00unlock_locmap_home_afternoon_std (lag 2)
#   steps_fitbit_steps_intraday_rapids_sumdurationactivebout_evening_slope (lag 2)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain_evening_std (lag 2)
#   slp_fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain_evening_std (lag 2)

# %%
# 2️⃣ Static total‐effect estimates via DirectLiNGAM
X_flat = X_t.reshape(-1, p)                # (T·N, p)
dlin    = DirectLiNGAM(random_state=0).fit(X_flat)

static_effects = []
for var, lag in parents:
    src = vars_all.index(var)
    tot = dlin.estimate_total_effect(X_flat, src, target)
    static_effects.append({
        "variable": var,
        "lag": lag,
        "total_effect": round(tot, 3)
    })

df_static = pd.DataFrame(static_effects)
print("\n=== Static Total Effects (all history collapsed) ===")
display(df_static)
# Out:
# === Static Total Effects (all history collapsed) ===
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=5).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=20).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=0).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=1).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=2).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=5).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=11).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=12).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=17).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=18).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=19).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=21).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=22).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=0).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=5).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=11).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=12).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=16).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=17).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=18).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=19).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=21).
#   warnings.warn(
# /Users/kwang/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/base.py:76: UserWarning: The estimated causal effect may be incorrect because the causal order of the destination variable (to_index=23) is earlier than the source variable (from_index=22).
#   warnings.warn(
#                                              variable  lag  total_effect
# 0   slp_fitbit_sleep_intraday_rapids_mindurationaw...    0        -0.047
# 1   slp_fitbit_sleep_summary_rapids_countepisodema...    0        -0.084
# 2   slp_fitbit_sleep_intraday_rapids_stddurationas...    0         0.079
# 3                                                 SRI    1        -0.020
# 4                                          dlmo_proxy    1        -0.015
# 5                                           sigma_bed    1        -0.007
# 6   slp_fitbit_sleep_intraday_rapids_mindurationaw...    1        -0.047
# 7   steps_fitbit_steps_intraday_rapids_minduration...    1         0.045
# 8   steps_fitbit_steps_intraday_rapids_minduration...    1         0.072
# 9   slp_fitbit_sleep_intraday_rapids_ratioduration...    1        -0.176
# 10  slp_fitbit_sleep_intraday_rapids_ratioduration...    1        -0.000
# 11  steps_fitbit_steps_intraday_rapids_avgduration...    1         0.001
# 12  screen_phone_screen_rapids_firstuseafter00unlo...    1        -0.060
# 13  steps_fitbit_steps_intraday_rapids_sumduration...    1        -0.039
# 14  slp_fitbit_sleep_intraday_rapids_ratioduration...    1         0.000
# 15  slp_fitbit_sleep_intraday_rapids_ratioduration...    1         0.109
# 16                                           PHQ4_dev    1         1.000
# 17                                                SRI    2        -0.020
# 18  slp_fitbit_sleep_intraday_rapids_mindurationaw...    2        -0.047
# 19  steps_fitbit_steps_intraday_rapids_minduration...    2         0.045
# 20  steps_fitbit_steps_intraday_rapids_minduration...    2         0.072
# 21  slp_fitbit_sleep_intraday_rapids_ratioduration...    2        -0.176
# 22  slp_fitbit_sleep_intraday_rapids_ratioduration...    2        -0.000
# 23  steps_fitbit_steps_intraday_rapids_avgduration...    2         0.055
# 24  steps_fitbit_steps_intraday_rapids_avgduration...    2         0.001
# 25  screen_phone_screen_rapids_firstuseafter00unlo...    2        -0.060
# 26  steps_fitbit_steps_intraday_rapids_sumduration...    2        -0.039
# 27  slp_fitbit_sleep_intraday_rapids_ratioduration...    2         0.000
# 28  slp_fitbit_sleep_intraday_rapids_ratioduration...    2         0.109

# %% [markdown]
# The code below takes way too long.

# %%
import warnings
from tqdm.notebook import tqdm
warnings.simplefilter("ignore", FutureWarning)
# 3️⃣ (Optional) Dynamic total‐effect from each lagged parent → PHQ4_dev(t)
dyn_eff = []
for var, lag in tqdm(parents):
    src = vars_all.index(var)
    try:
        eff_dyn = model.estimate_total_effect2(
            from_t    = lag,
            from_index= src,
            to_t      = t_last,
            to_index  = target
        )
    except ValueError:
        # no valid causal order for t=0 slices, skip
        continue
    dyn_eff.append({
        "variable": var,
        "from_time": f"t-{lag}",
        "to_time": f"t",
        "dynamic_total_effect": round(eff_dyn, 3)
    })

df_dyn = pd.DataFrame(dyn_eff)
print("\n=== Dynamic Total Effects (per lag) ===")
display(df_dyn)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 9
#       7 src = vars_all.index(var)
#       8 try:
# ----> 9     eff_dyn = model.estimate_total_effect2(
#      10         from_t    = lag,
#      11         from_index= src,
#      12         to_t      = t_last,
#      13         to_index  = target
#      14     )
#      15 except ValueError:
#      16     # no valid causal order for t=0 slices, skip
#      17     continue
#
# File ~/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/longitudinal_lingam.py:371, in LongitudinalLiNGAM.estimate_total_effect2(self, from_t, from_index, to_t, to_index)
#     368             continue
#     369         expansion_m[row : row + n_features, col : col + n_features] = self._adjacency_matrices[t, tau]
# --> 371 effect = calculate_total_effect(expansion_m, from_index, n_features * (to_t - from_t) + to_index)
#     373 return effect
#
# File ~/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/utils/__init__.py:1137, in calculate_total_effect(adjacency_matrix, from_index, to_index, is_continuous)
#    1132     is_continuous = check_array(
#    1133         is_continuous, ensure_2d=False, ensure_min_samples=len(adjacency_matrix)
#    1134     )
#    1136 # find all paths
# -> 1137 path_list, effects = find_all_paths(adjacency_matrix, from_index, to_index)
#    1139 # check all nodes on the path are continuous
#    1140 for path in path_list:
#
# File ~/.local/share/mamba/envs/lingam-env/lib/python3.10/site-packages/lingam/utils/__init__.py:830, in find_all_paths(dag, from_index, to_index, min_causal_effect)
#     828 stack_to_indice = [to_indices[from_index]]
#     829 while stack:
# --> 830     if len(stack) > dag.shape[0]:
#     831         raise ValueError(
#     832             "Unable to find the path because a cyclic graph has been specified."
#     833         )
#     835     cur_index = stack[-1]
#
# KeyboardInterrupt:

# %% [markdown]
# Individual estimation is very difficult.
#
# Below is a recipe for “per‐individual” causal effects, in two senses:
#
# Dynamic direct effects by subject & time (weights are the same across subjects, but you can record them per‐subject/time)
#
# True subject‐specific effects by refitting a separate LiNGAM on each person (only possible if you have enough timepoints per subject), but we don't have enough timepoints per subject.
