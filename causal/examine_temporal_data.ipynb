# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

list_pids = ["INS-W_335", 
             "INS-W_336",
             "INS-W_344",
             "INS-W_360",
             "INS-W_427",
             "INS-W_504",
             "INS-W_508",
             "INS-W_518",
             "INS-W_537",
             "INS-W_541",
             "INS-W_698",
             "INS-W_701",
             "INS-W_744",
             "INS-W_746",
             "INS-W_751",
             "INS-W_913",
             "INS-W_974",
             "INS-W_991",
             "INS-W_1000",
             "INS-W_1031",
             "INS-W_1038",
             "INS-W_1081",
             ]



def find_pid_folder(pid: str, data_root: str = "data/globem_raw/") -> str:
    """
    Given a pid (e.g., 'INS-W_541'), determine which INS-W folder it belongs to.

    Args:
        pid (str): The participant ID to search for.
        data_root (str): Base directory where INS-W_1, INS-W_2, etc. are stored.

    Returns:
        str: The folder name (e.g., 'INS-W_2') if found.

    Raises:
        FileNotFoundError: If the PID is not found in any folder.
    """
    for folder in ["INS-W_1", "INS-W_2", "INS-W_3", "INS-W_4"]:
        label_path = os.path.join(data_root, folder, "SurveyData", "dep_weekly.csv")
        if os.path.exists(label_path):
            df = pd.read_csv(label_path)
            if pid in df["pid"].values:
                return folder
    raise FileNotFoundError(f"PID {pid} not found in any INS-W folder.")

def load_subject_tables(pid: str, folder: str, data_root: str = "data/globem_raw/"):
    """
    Loads and filters the features and labels for a given subject.

    Args:
        pid (str): Participant ID (e.g., 'INS-W_541')
        folder (str): INS-W folder name (e.g., 'INS-W_2') as returned by `find_pid_folder()`
        data_root (str): Base directory for GLOBEM data.

    Returns:
        tuple: (pid_features_df, pid_labels_df)
    """
    # Read feature and label files
    features_path = os.path.join(data_root, folder, "FeatureData", "rapids.csv")
    labels_path = os.path.join(data_root, folder, "SurveyData", "dep_weekly.csv")

    features_df = pd.read_csv(features_path)
    labels_df = pd.read_csv(labels_path)

    # Filter labels
    labels_df = labels_df.loc[labels_df["pid"] == pid].drop(columns=["Unnamed: 0"], errors='ignore')

    # Filter features: keep only certain types, exclude others
    pid_features_df = features_df.loc[
        features_df["pid"] == pid,
        features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
        & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")
    ]

    return pid_features_df, labels_df


def plot_sleep_and_phq4(pid_features_df: pd.DataFrame, pid_labels_df: pd.DataFrame, pid: str = None, save_df = False):
    """
    Plot first bedtime and first wake time alongside PHQ4 scores for a subject.

    Args:
        pid_features_df (pd.DataFrame): Filtered feature dataframe for one subject.
        pid_labels_df (pd.DataFrame): Filtered label dataframe for one subject.
        pid (str, optional): PID to show in the plot title (optional).
    """
    # Feature names to use
    features_to_plot = {
        "bed": "f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday",
        "wake": "f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday"
    }

    # Merge features with PHQ4 scores on date
    merged_df = pd.merge(
        pid_features_df[["date"] + list(features_to_plot.values())],
        pid_labels_df[["date", "phq4"]],
        on="date",
        how="left"
    )

    # Ensure datetime
    merged_df["date"] = pd.to_datetime(merged_df["date"])

    # Convert to hours after midnight
    merged_df["first_bed_hr"] = merged_df[features_to_plot["bed"]] / 60
    merged_df["first_wake_hr"] = merged_df[features_to_plot["wake"]] / 60

    # Sort for time series plotting
    merged_df = merged_df.sort_values("date")

    if save_df:
        merged_df.to_csv(f"data/processed/{pid}_features_labels.csv", index=False)

    # Create figure
    fig, ax1 = plt.subplots(figsize=(12, 6))

    # Plot sleep features
    ax1.plot(merged_df["date"], merged_df["first_bed_hr"], marker='o', label="First Bedtime (hr)")
    ax1.plot(merged_df["date"], merged_df["first_wake_hr"], marker='o', label="First Wake Time (hr)")

    ax1.set_xlabel("Date")
    ax1.set_ylabel("Sleep Time (hours after midnight)")

    # Tick labels only on PHQ4 dates
    phq4_dates = merged_df.loc[merged_df["phq4"].notna(), "date"]
    ax1.set_xticks(phq4_dates)
    ax1.set_xticklabels(phq4_dates.dt.strftime('%Y-%m-%d'), rotation=45)

    # Plot PHQ4 scores on secondary y-axis
    ax2 = ax1.twinx()
    phq4_series = merged_df[["date", "phq4"]].dropna().sort_values("date")
    ax2.plot(phq4_series["date"], phq4_series["phq4"], color='black', marker='s', linestyle='--', label='PHQ4 Score')
    ax2.set_ylabel("PHQ4 Score")

    # Set y-limits for clarity
    y_min = int(np.floor(merged_df["first_wake_hr"].min()))
    y_max = int(np.floor(merged_df["first_bed_hr"].max()) + 1)
    y_ticks = list(range(y_min, y_max))  # 4 to 30 inclusive
    y_tick_labels = [str(tick if tick < 24 else tick - 24) for tick in y_ticks]
    y_tick_labels = [str(tick if tick >= 0 else tick + 24) for tick in y_ticks]

    ax1.set_yticks(y_ticks)
    ax1.set_yticklabels(y_tick_labels)

    ax1.set_ylabel("Sleep Time (hours)")

    # Combine legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper left')

    # Title
    title = f"First Bedtime / Wake Time and PHQ4 over Time"
    if pid is not None:
        title += f" (PID: {pid})"
    plt.title(title)

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("data/processed/phq4_ts_features.csv")

# 1) Per-feature missing counts (optional)
missing_per_feature = df.isna().sum()
print("Missing cells per feature:")
display(missing_per_feature.to_frame(name="missing_count"))

# 2) Per-subject × per-feature missing counts
missing_matrix = df.groupby("pid").apply(lambda g: g.isna().sum())

# If 'pid' became a column in the result, drop it
missing_matrix = missing_matrix.drop(columns=["pid"], errors="ignore")

# Display the full matrix
print("\nMissing cells per subject and feature:")
display(missing_matrix)
# Out:
# Missing cells per feature:
#                                                     missing_count
# pid                                                             0
# PHQ4_date                                                       0
# PHQ4                                                            0
# Days                                                            0
# SRI                                                           112
# IS                                                            112
# sigma_bed                                                     112
# mid_sleep                                                     112
# dlmo_proxy                                                    112
# f_screen:phone_screen_rapids_sumdurationunlock_...             33
# f_screen:phone_screen_rapids_sumdurationunlock_...             33
# f_screen:phone_screen_rapids_sumdurationunlock:...              8
# f_screen:phone_screen_rapids_sumdurationunlock:...              8
# f_screen:phone_screen_rapids_sumdurationunlock:...              0
# f_screen:phone_screen_rapids_sumdurationunlock:...              0
# f_steps:fitbit_steps_intraday_rapids_countepiso...             85
# f_steps:fitbit_steps_intraday_rapids_countepiso...             85
# f_steps:fitbit_steps_intraday_rapids_avgduratio...             85
# f_steps:fitbit_steps_intraday_rapids_avgduratio...             85
# f_steps:fitbit_steps_intraday_rapids_sumsteps:a...             85
# f_steps:fitbit_steps_intraday_rapids_sumsteps:a...             85
# Missing cells per subject and feature:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1841597273.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_matrix = df.groupby("pid").apply(lambda g: g.isna().sum())
#             PHQ4_date  PHQ4  Days  SRI  IS  sigma_bed  mid_sleep  dlmo_proxy  \
# pid
# INS-W_1000          0     0     0    0   0          0          0           0
# INS-W_1002          0     0     0    0   0          0          0           0
# INS-W_1003          0     0     0    0   0          0          0           0
# INS-W_1004          0     0     0    0   0          0          0           0
# INS-W_1006          0     0     0    0   0          0          0           0
# ...               ...   ...   ...  ...  ..        ...        ...         ...
# INS-W_994           0     0     0    0   0          0          0           0
# INS-W_995           0     0     0    0   0          0          0           0
# INS-W_996           0     0     0    0   0          0          0           0
# INS-W_998           0     0     0    0   0          0          0           0
# INS-W_999           0     0     0    0   0          0          0           0
#
#             f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night_std  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_screen:phone_screen_rapids_sumdurationunlock:night_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_screen:phone_screen_rapids_sumdurationunlock:night_std  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_screen:phone_screen_rapids_sumdurationunlock:allday_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_screen:phone_screen_rapids_sumdurationunlock:allday_std  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:allday_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:allday_std  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday_std  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_sumsteps:allday_mean  \
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
#             f_steps:fitbit_steps_intraday_rapids_sumsteps:allday_std
# pid
# INS-W_1000                                                  0
# INS-W_1002                                                  0
# INS-W_1003                                                  0
# INS-W_1004                                                  0
# INS-W_1006                                                  0
# ...                                                       ...
# INS-W_994                                                   0
# INS-W_995                                                   0
# INS-W_996                                                   0
# INS-W_998                                                   0
# INS-W_999                                                   0
#
# [530 rows x 20 columns]

# %%
df_clean = df.dropna(axis=0, how='any')
(df_clean["pid"].value_counts() > 6).sum()
# Out:
# np.int64(493)

# %% [markdown]
# # Example subject plots

# %%
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)

# %%
pid_features_df.loc[:, "f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday"].notna().sum()
# Out:
# np.int64(0)

# %%
index = 0
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid, save_df=True)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid, save_df=True)

# %%
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/357394554.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/357394554.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/357394554.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
pid_features_df.loc[:, "f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday"].notna().sum()
# Out:
# np.int64(65)

# %%
index = 2
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
pid_features_df.loc[:, "f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday"].notna().sum()
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/3406277927.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 3
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1439005198.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1439005198.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1439005198.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 4
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/415550633.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/415550633.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/415550633.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 5
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
pid_features_df.to_csv("example_pid_features_df.csv", index=False)
pid_labels_df.to_csv("examine_pid_labels_df.csv", index=False)

# %%
index = 6
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 7
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 8
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 9
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 10
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (252,286,296,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,864,876,898,908,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1472,1473,1474,1475,1476,1477,1478,1479,1480,1484,1485,1486,1487,1488,1489,1490,1491,1492,1500,1510,1520,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2100,2112,2122,2132,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2719,2720,2721,2722,2723,2724,2725,2726,2727,2728,2729,2730,2731,2732,2733,2734,2735,2736,2737,2738,2739,2740,2741,2742,2743,2744,2745,2746,2747,2748,2749,2750,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3942,3943,3944,3945,3946,3947,3948,3949,3950,3951,3952,3953,3954,3955,3956,3957,3958,3959,3960,3961,3962,3963,3964,3965,3966,3967,3968,3969,3970,3971,3972,3973,3974,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4548,4570,4580,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5166,5167,5168,5169,5170,5171,5172,5173,5174,5175,5176,5177,5178,5179,5180,5181,5182,5183,5184,5185,5186,5187,5188,5189,5190,5191,5192,5193,5194,5195,5196,5197,5198,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 11
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (252,286,296,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,864,876,898,908,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1472,1473,1474,1475,1476,1477,1478,1479,1480,1484,1485,1486,1487,1488,1489,1490,1491,1492,1500,1510,1520,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2100,2112,2122,2132,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2719,2720,2721,2722,2723,2724,2725,2726,2727,2728,2729,2730,2731,2732,2733,2734,2735,2736,2737,2738,2739,2740,2741,2742,2743,2744,2745,2746,2747,2748,2749,2750,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3942,3943,3944,3945,3946,3947,3948,3949,3950,3951,3952,3953,3954,3955,3956,3957,3958,3959,3960,3961,3962,3963,3964,3965,3966,3967,3968,3969,3970,3971,3972,3973,3974,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4548,4570,4580,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5166,5167,5168,5169,5170,5171,5172,5173,5174,5175,5176,5177,5178,5179,5180,5181,5182,5183,5184,5185,5186,5187,5188,5189,5190,5191,5192,5193,5194,5195,5196,5197,5198,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 12
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (252,286,296,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,864,876,898,908,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1472,1473,1474,1475,1476,1477,1478,1479,1480,1484,1485,1486,1487,1488,1489,1490,1491,1492,1500,1510,1520,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2100,2112,2122,2132,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2719,2720,2721,2722,2723,2724,2725,2726,2727,2728,2729,2730,2731,2732,2733,2734,2735,2736,2737,2738,2739,2740,2741,2742,2743,2744,2745,2746,2747,2748,2749,2750,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3942,3943,3944,3945,3946,3947,3948,3949,3950,3951,3952,3953,3954,3955,3956,3957,3958,3959,3960,3961,3962,3963,3964,3965,3966,3967,3968,3969,3970,3971,3972,3973,3974,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4548,4570,4580,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5166,5167,5168,5169,5170,5171,5172,5173,5174,5175,5176,5177,5178,5179,5180,5181,5182,5183,5184,5185,5186,5187,5188,5189,5190,5191,5192,5193,5194,5195,5196,5197,5198,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 13
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (252,286,296,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,864,876,898,908,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1472,1473,1474,1475,1476,1477,1478,1479,1480,1484,1485,1486,1487,1488,1489,1490,1491,1492,1500,1510,1520,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2100,2112,2122,2132,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2719,2720,2721,2722,2723,2724,2725,2726,2727,2728,2729,2730,2731,2732,2733,2734,2735,2736,2737,2738,2739,2740,2741,2742,2743,2744,2745,2746,2747,2748,2749,2750,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3942,3943,3944,3945,3946,3947,3948,3949,3950,3951,3952,3953,3954,3955,3956,3957,3958,3959,3960,3961,3962,3963,3964,3965,3966,3967,3968,3969,3970,3971,3972,3973,3974,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4548,4570,4580,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5166,5167,5168,5169,5170,5171,5172,5173,5174,5175,5176,5177,5178,5179,5180,5181,5182,5183,5184,5185,5186,5187,5188,5189,5190,5191,5192,5193,5194,5195,5196,5197,5198,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 14
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (252,286,296,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,864,876,898,908,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1472,1473,1474,1475,1476,1477,1478,1479,1480,1484,1485,1486,1487,1488,1489,1490,1491,1492,1500,1510,1520,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2100,2112,2122,2132,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2719,2720,2721,2722,2723,2724,2725,2726,2727,2728,2729,2730,2731,2732,2733,2734,2735,2736,2737,2738,2739,2740,2741,2742,2743,2744,2745,2746,2747,2748,2749,2750,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3942,3943,3944,3945,3946,3947,3948,3949,3950,3951,3952,3953,3954,3955,3956,3957,3958,3959,3960,3961,3962,3963,3964,3965,3966,3967,3968,3969,3970,3971,3972,3973,3974,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4548,4570,4580,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5166,5167,5168,5169,5170,5171,5172,5173,5174,5175,5176,5177,5178,5179,5180,5181,5182,5183,5184,5185,5186,5187,5188,5189,5190,5191,5192,5193,5194,5195,5196,5197,5198,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 15
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (286,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,898,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1476,1510,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2122,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2712,2734,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3303,3304,3308,3309,3310,3311,3312,3313,3314,3315,3316,3320,3321,3322,3323,3324,3325,3326,3327,3328,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4570,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5139,5140,5144,5145,5146,5147,5148,5149,5150,5151,5152,5156,5157,5158,5159,5160,5161,5162,5163,5164,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5241,5242,5243,5244,5245,5246,5247,5248,5249,5250,5251,5252,5253,5254,5255,5256,5257,5258,5259,5260,5261,5262,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 16
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (286,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,898,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1476,1510,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2122,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2712,2734,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3303,3304,3308,3309,3310,3311,3312,3313,3314,3315,3316,3320,3321,3322,3323,3324,3325,3326,3327,3328,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4570,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5139,5140,5144,5145,5146,5147,5148,5149,5150,5151,5152,5156,5157,5158,5159,5160,5161,5162,5163,5164,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5241,5242,5243,5244,5245,5246,5247,5248,5249,5250,5251,5252,5253,5254,5255,5256,5257,5258,5259,5260,5261,5262,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 17
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (286,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,898,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1476,1510,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2122,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2712,2734,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3303,3304,3308,3309,3310,3311,3312,3313,3314,3315,3316,3320,3321,3322,3323,3324,3325,3326,3327,3328,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4570,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5139,5140,5144,5145,5146,5147,5148,5149,5150,5151,5152,5156,5157,5158,5159,5160,5161,5162,5163,5164,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5241,5242,5243,5244,5245,5246,5247,5248,5249,5250,5251,5252,5253,5254,5255,5256,5257,5258,5259,5260,5261,5262,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 18
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:71: DtypeWarning: Columns (286,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,367,368,369,370,371,372,373,374,375,376,377,378,379,380,898,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,979,980,981,982,983,984,985,986,987,988,989,990,991,992,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1476,1510,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,2088,2122,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2203,2204,2205,2206,2207,2208,2209,2210,2211,2212,2213,2214,2215,2216,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2691,2692,2700,2712,2734,2758,2759,2760,2761,2762,2763,2764,2765,2766,2767,2768,2769,2770,2771,2772,2773,2774,2775,2776,2777,2778,2779,2780,2781,2782,2783,2784,2785,3303,3304,3308,3309,3310,3311,3312,3313,3314,3315,3316,3320,3321,3322,3323,3324,3325,3326,3327,3328,3336,3346,3356,3370,3371,3372,3373,3374,3375,3376,3377,3378,3379,3380,3381,3382,3383,3384,3385,3386,3387,3388,3389,3390,3391,3392,3393,3394,3395,3396,3397,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4536,4570,4594,4595,4596,4597,4598,4599,4600,4601,4602,4603,4604,4605,4606,4607,4608,4609,4610,4611,4612,4613,4614,4615,4616,4617,4618,4619,4620,4621,4651,4652,4653,4654,4655,4656,4657,4658,4659,4660,4661,4662,4663,4664,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5139,5140,5144,5145,5146,5147,5148,5149,5150,5151,5152,5156,5157,5158,5159,5160,5161,5162,5163,5164,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5241,5242,5243,5244,5245,5246,5247,5248,5249,5250,5251,5252,5253,5254,5255,5256,5257,5258,5259,5260,5261,5262,5263,5264,5265,5266,5267,5268,5269,5270,5271,5272,5273,5274,5275,5276) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_path)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:80: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/965666801.py:81: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
index = 19
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)

# %%
index = 20
pid = list_pids[index]
folder = find_pid_folder(pid)
pid_features_df, pid_labels_df = load_subject_tables(pid, folder)
plot_sleep_and_phq4(pid_features_df, pid_labels_df, pid=pid)

# %% [markdown]
# # metric calculation

# %%
import pandas as pd, numpy as np
from datetime import timedelta, datetime

FILE = "data/processed/INS-W_335_features_labels.csv"
df = pd.read_csv(FILE, parse_dates=["date"])
df = df.dropna(subset=["first_bed_hr", "first_wake_hr"]).copy()

# Pre‑compute mod‑24 clock times
df["bed_mod"]  = df["first_bed_hr"]  % 24
df["wake_mod"] = df["first_wake_hr"] % 24

MINUTES_PER_DAY = 1440

def day_vector(bed, wake):
    """Return a 1440-length binary vector (1 = asleep) for one day."""
    vec = np.zeros(MINUTES_PER_DAY, dtype=int)
    b = int(round(bed * 60)) % MINUTES_PER_DAY
    w = int(round(wake * 60)) % MINUTES_PER_DAY
    if w > b:                   # sleep starts & ends the same calendar day
        vec[b:w] = 1
    else:                       # crosses midnight
        vec[b:] = 1
        vec[:w] = 1
    return vec

def metrics_for_window(win):
    mat = np.stack([day_vector(b, w) for b, w in zip(win["bed_mod"], win["wake_mod"])])
    series = mat.flatten()

    # --- Sleep Regularity Index (Phillips 2017) --------------------
    aligned = series[:-MINUTES_PER_DAY] == series[MINUTES_PER_DAY:]
    sri = 200 * aligned.mean() - 100

    # --- Interdaily Stability (IS) --------------------------------
    grand = series.mean()
    avg24 = mat.mean(axis=0)
    is_val = ((avg24 - grand)**2).sum() / ((series - grand)**2).sum()

    # --- Bed‑time scatter -----------------------------------------
    bed_sd = win["bed_mod"].std()

    # --- Mid‑sleep chronotype -------------------------------------
    mids = []
    for b, w in zip(win["bed_mod"], win["wake_mod"]):
        dur = (w - b) % 24
        mids.append((b + dur / 2) % 24)
    mid_sleep = np.mean(mids)

    dlmo_proxy = (win["bed_mod"].mean() - 2) % 24
    return sri, is_val, bed_sd, mid_sleep, dlmo_proxy

# ------------------------------------------------------------------
# Build windows between successive PHQ‑4 assessments
phq = df[~df["phq4"].isna()].sort_values("date")[["date", "phq4"]]

records = []
for i in range(1, len(phq)):
    start = phq.iloc[i-1]["date"]
    end   = phq.iloc[i]["date"]
    win   = df[(df["date"] >= start) & (df["date"] < end)]
    if len(win) < 2:            # need ≥2 days for SRI
        continue
    sri, is_val, bed_sd, ms, dlmo = metrics_for_window(win)
    records.append({
        "PHQ-4 date": end.date(),
        "PHQ-4": phq.iloc[i]["phq4"],
        "Days": len(win),
        "SRI": round(sri, 1),
        "IS": round(is_val, 3),
        "sigma_bed (h)": round(bed_sd, 2),
        "Mid-sleep (h)": round(ms, 2),
        "DLMO proxy (h)": round(dlmo, 2)
    })

out = pd.DataFrame(records)
out
# Out:
#    PHQ-4 date  PHQ-4  Days   SRI     IS  sigma_bed (h)  Mid-sleep (h)  \
# 0  2019-04-07    7.0     7  79.0  0.093           0.92           5.52
# 1  2019-04-11    4.0     4  83.3  0.192           0.40           5.60
# 2  2019-04-21    4.0    10  70.0  0.058           6.48           5.99
# 3  2019-04-28    4.0     7  75.4  0.091           0.64           6.03
# 4  2019-05-05    4.0     7  71.5  0.093           0.77           6.03
# 5  2019-05-09    6.0     4  77.9  0.181           0.56           5.73
# 6  2019-05-19    7.0    10  59.1  0.051           5.74           5.58
# 7  2019-05-26   12.0     7  71.9  0.090           1.17           6.03
#
#    DLMO proxy (h)
# 0            0.65
# 1            0.81
# 2            3.07
# 3            0.86
# 4            0.73
# 5            0.76
# 6            3.03
# 7            0.68

# %%
import pandas as pd, numpy as np
from datetime import timedelta

def impute_sleep_times(df, bed_col="first_bed_hr", wake_col="first_wake_hr", date_col="date"):
    """
    Linearly interpolate missing bedtime and wake‑time values.
    Forward/Backward fill for leading/trailing NaNs.
    """
    df = df.sort_values(date_col).copy()
    for col in [bed_col, wake_col]:
        df[col] = df[col].interpolate(method="linear", limit_direction="both")
    return df

def day_vector(bed_hr, wake_hr):
    """
    Return a 1440-long binary vector (1=asleep) for a single day,
    given bed & wake time in hours since midnight (mod‑24).
    Handles cross-midnight sleep.
    """
    MINUTES = 1440
    vec = np.zeros(MINUTES, dtype=int)
    b = int(round(bed_hr * 60)) % MINUTES
    w = int(round(wake_hr * 60)) % MINUTES
    if w > b:
        vec[b:w] = 1
    else:
        vec[b:] = 1
        vec[:w] = 1
    return vec

def window_metrics(win_df, bed_col="first_bed_hr", wake_col="first_wake_hr"):
    """Compute SRI, IS, bedtime SD, mid‑sleep, DLMO proxy for a window of days."""
    mats = np.stack([day_vector(b%24, w%24) for b, w in zip(win_df[bed_col], win_df[wake_col])])
    series = mats.flatten()
    MINUTES = 1440
    sri = 200 * (series[:-MINUTES] == series[MINUTES:]).mean() - 100
    grand = series.mean()
    is_val = ((mats.mean(axis=0) - grand)**2).sum() / ((series - grand)**2).sum()
    bed_sd = (win_df[bed_col] % 24).std()
    mids = [((b%24) + ((w-b)%24)/2) % 24 for b, w in zip(win_df[bed_col], win_df[wake_col])]
    mid_sleep = np.mean(mids)
    dlmo_proxy = ((win_df[bed_col] % 24).mean() - 2) % 24
    return sri, is_val, bed_sd, mid_sleep, dlmo_proxy

def circadian_metrics_by_phq_window(df,
                                    bed_col="first_bed_hr",
                                    wake_col="first_wake_hr",
                                    phq_col="phq4",
                                    date_col="date"):
    """
    Impute missing sleep times, then compute circadian metrics
    for each window between consecutive PHQ assessments.
    """
    df = impute_sleep_times(df, bed_col, wake_col, date_col)
    phq = df[~df[phq_col].isna()].sort_values(date_col)[[date_col, phq_col]]
    records = []
    for i in range(1, len(phq)):
        start, end = phq.iloc[i-1][date_col], phq.iloc[i][date_col]
        window = df[(df[date_col] >= start) & (df[date_col] < end)]
        if len(window) < 2:
            continue
        sri, is_val, bed_sd, mid_sleep, dlmo = window_metrics(window, bed_col, wake_col)
        records.append({
            "PHQ_date": end.date(),
            "PHQ": phq.iloc[i][phq_col],
            "Days": len(window),
            "SRI": round(sri, 1),
            "IS": round(is_val, 3),
            "σ_bed(h)": round(bed_sd, 2),
            "Mid_sleep(h)": round(mid_sleep, 2),
            "DLMO_proxy(h)": round(dlmo, 2)
        })
    return pd.DataFrame(records)

# ------------------ Demo on user's CSV ----------------------------
FILE = "data/processed/INS-W_335_features_labels.csv"
data = pd.read_csv(FILE, parse_dates=["date"])
result_table = circadian_metrics_by_phq_window(data)
result_table
# Out:
#      PHQ_date   PHQ  Days   SRI     IS  σ_bed(h)  Mid_sleep(h)  DLMO_proxy(h)
# 0  2019-04-07   7.0     7  79.0  0.093      0.92          5.52           0.65
# 1  2019-04-11   4.0     4  83.3  0.192      0.40          5.60           0.81
# 2  2019-04-21   4.0    10  70.0  0.058      6.48          5.99           3.07
# 3  2019-04-28   4.0     7  75.4  0.091      0.64          6.03           0.86
# 4  2019-05-05   4.0     7  71.5  0.093      0.77          6.03           0.73
# 5  2019-05-09   6.0     4  77.9  0.181      0.56          5.73           0.76
# 6  2019-05-19   7.0    10  59.1  0.051      5.74          5.58           3.03
# 7  2019-05-26  12.0     7  71.9  0.090      1.17          6.03           0.68
# 8  2019-06-02  11.0     7  88.9  0.118      0.22          5.47           0.56

# %% [markdown]
# # Scrap

# %%
index = 0

data_dir = "data/globem_raw/"

features_dir = "data/globem_raw/INS-W_2/FeatureData/rapids.csv"

features_df = pd.read_csv(features_dir)

labels_dir = "data/globem_raw/INS-W_2/SurveyData/dep_weekly.csv"

labels_df = pd.read_csv(labels_dir)

labels_df = labels_df.loc[labels_df["pid"].eq(list_pids[index]),:]
labels_df = labels_df.drop(columns=["Unnamed: 0"], axis=1)

pid_features_df = features_df.loc[
    features_df["pid"].eq(list_pids[index]),
    features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
    & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")
]

pid_labels_df = labels_df.loc[labels_df["pid"] == list_pids[0], :]

import pandas as pd
import matplotlib.pyplot as plt

# Features to use
features_to_plot = {
    "bed": "f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday",
    "wake": "f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday"
}

# Merge features with PHQ4 scores
merged_df = pd.merge(
    pid_features_df[["date"] + list(features_to_plot.values())],
    pid_labels_df[["date", "phq4"]],
    on="date",
    how="left"
)

# Ensure datetime type for plotting and tick formatting
merged_df["date"] = pd.to_datetime(merged_df["date"])

# Convert minutes to hours after midnight
merged_df["first_bed_hr"] = merged_df[features_to_plot["bed"]] / 60
merged_df["first_wake_hr"] = merged_df[features_to_plot["wake"]] / 60

# Sort by date to ensure consistent time series
merged_df = merged_df.sort_values("date")

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot sleep features
ax1.plot(merged_df["date"], merged_df["first_bed_hr"], marker='o', label="First Bedtime (hr)")
ax1.plot(merged_df["date"], merged_df["first_wake_hr"], marker='o', label="First Wake Time (hr)")

ax1.set_xlabel("Date")
ax1.set_ylabel("Sleep Time (hours after midnight)")

# Restrict x-axis ticks to PHQ4 available dates
phq4_dates = merged_df.loc[merged_df["phq4"].notna(), "date"]
ax1.set_xticks(phq4_dates)
ax1.set_xticklabels(phq4_dates.dt.strftime('%Y-%m-%d'), rotation=45)

# PHQ4 scores on secondary axis
ax2 = ax1.twinx()
phq4_series = merged_df[["date", "phq4"]].dropna().sort_values("date")
ax2.plot(phq4_series["date"], phq4_series["phq4"], color='black', marker='s', linestyle='--', label='PHQ4 Score')
ax2.set_ylabel("PHQ4 Score")

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.title("First Bedtime / Wake Time and PHQ4 over Time")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1704941255.py:36: DtypeWarning: Columns (207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,286,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,408,409,410,855,856,872,873,874,875,876,877,878,879,880,898,1020,1021,1022,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1510,1539,1632,1633,1634,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2122,2244,2245,2246,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2704,2705,2706,2707,2708,2709,2710,2711,2712,2713,2714,2715,2716,2717,2734,2758,2759,2760,2761,2762,2763,2764,2770,2772,2773,2774,2775,2776,2777,2778,2856,2857,2858,3283,3284,3285,3286,3287,3288,3289,3290,3291,3292,3293,3294,3295,3296,3297,3298,3299,3300,3301,3302,3303,3304,3305,3306,3307,3308,3309,3310,3311,3312,3313,3314,3315,3316,3317,3318,3319,3320,3321,3322,3323,3324,3325,3326,3327,3328,3329,3346,3370,3371,3372,3373,3374,3375,3376,3384,3385,3386,3387,3388,3389,3390,3468,3469,3470,3895,3896,3897,3898,3899,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3932,3933,3934,3935,3936,3937,3938,3939,3940,3941,3948,3958,3968,3982,3983,3984,3985,3986,3987,3988,3989,3990,3991,3992,3993,3994,3995,3996,3997,3998,3999,4000,4001,4002,4003,4004,4005,4006,4007,4008,4009,4080,4081,4082,4491,4492,4493,4494,4495,4496,4497,4498,4499,4500,4501,4502,4503,4504,4505,4506,4507,4508,4509,4510,4511,4512,4513,4514,4515,4516,4517,4518,4519,4520,4521,4522,4523,4524,4525,4526,4527,4528,4529,4530,4531,4532,4533,4534,4535,4536,4537,4538,4539,4540,4541,4542,4543,4544,4545,4546,4547,4548,4549,4550,4551,4552,4553,4570,4692,4693,4694,5103,5104,5105,5106,5107,5108,5109,5110,5111,5112,5113,5114,5115,5116,5117,5118,5119,5120,5121,5122,5123,5124,5125,5126,5127,5128,5129,5130,5131,5132,5133,5134,5135,5136,5137,5138,5139,5140,5141,5142,5143,5144,5145,5146,5147,5148,5149,5150,5151,5152,5153,5154,5155,5156,5157,5158,5159,5160,5161,5162,5163,5164,5165,5182,5206,5207,5208,5209,5210,5211,5212,5213,5214,5215,5216,5217,5218,5219,5220,5221,5222,5223,5224,5225,5226,5227,5228,5229,5230,5231,5232,5233,5304,5305,5306) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(features_dir)
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1704941255.py:47: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   features_df.columns.str.contains(r"^(f_slp:fitbit|f_screen:phone|f_steps:fitbit|pid|date)")
# /var/folders/j_/3nq1pt5x6yqcx3k5d68vn4mc0000gq/T/ipykernel_3065/1704941255.py:48: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~features_df.columns.str.contains(r"(14dhist|7dhist|_dis:|_norm:|weekday|weekend)")

# %%
labels_df
# Out:
#            pid        date  phq4   dep  BDI2 dep_weekly_subscale  \
# 304  INS-W_335  2019-03-31   4.0  True   NaN               False
# 305  INS-W_335  2019-04-07   7.0  True   NaN                True
# 306  INS-W_335  2019-04-11   4.0  True   NaN               False
# 307  INS-W_335  2019-04-21   4.0  True   NaN               False
# 308  INS-W_335  2019-04-28   4.0  True   NaN               False
# 309  INS-W_335  2019-05-05   4.0  True   NaN               False
# 310  INS-W_335  2019-05-09   6.0  True   NaN                True
# 311  INS-W_335  2019-05-19   7.0  True   NaN                True
# 312  INS-W_335  2019-05-26  12.0  True   NaN                True
# 313  INS-W_335  2019-06-02  11.0  True   NaN                True
# 314  INS-W_335  2019-06-08   NaN  True  34.0                 NaN
#
#     anx_weekly_subscale  dep_weeklysubscale_endterm_merged
# 304               False                              False
# 305                True                               True
# 306               False                              False
# 307               False                              False
# 308               False                              False
# 309               False                              False
# 310                True                               True
# 311                True                               True
# 312                True                               True
# 313                True                               True
# 314                 NaN                               True

# %%
features_notna_count = pid_features_df.notna().sum()
valid_features = features_notna_count[features_notna_count>=50]
print(valid_features.shape)
for k,v in valid_features.to_dict().items():
    print(k, v)
# Out:
# (170,)
# pid 97
# date 97
# f_screen:phone_screen_rapids_countepisodeunlock:afternoon 79
# f_screen:phone_screen_rapids_sumdurationunlock:afternoon 79
# f_screen:phone_screen_rapids_maxdurationunlock:afternoon 79
# f_screen:phone_screen_rapids_mindurationunlock:afternoon 79
# f_screen:phone_screen_rapids_avgdurationunlock:afternoon 79
# f_screen:phone_screen_rapids_stddurationunlock:afternoon 79
# f_screen:phone_screen_rapids_firstuseafter00unlock:afternoon 79
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:afternoon 57
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:afternoon 61
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:afternoon 58
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:afternoon 58
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:allday 65
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday 65
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:allday 65
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:allday 65
# f_screen:phone_screen_rapids_countepisodeunlock:allday 80
# f_screen:phone_screen_rapids_sumdurationunlock:allday 80
# f_screen:phone_screen_rapids_maxdurationunlock:allday 80
# f_screen:phone_screen_rapids_mindurationunlock:allday 80
# f_screen:phone_screen_rapids_avgdurationunlock:allday 80
# f_screen:phone_screen_rapids_stddurationunlock:allday 80
# f_screen:phone_screen_rapids_firstuseafter00unlock:allday 80
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:allday 63
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:allday 61
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:allday 76
# f_screen:phone_screen_rapids_countepisodeunlock:evening 79
# f_screen:phone_screen_rapids_sumdurationunlock:evening 79
# f_screen:phone_screen_rapids_maxdurationunlock:evening 79
# f_screen:phone_screen_rapids_mindurationunlock:evening 79
# f_screen:phone_screen_rapids_avgdurationunlock:evening 79
# f_screen:phone_screen_rapids_stddurationunlock:evening 79
# f_screen:phone_screen_rapids_firstuseafter00unlock:evening 79
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:evening 65
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:evening 65
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:evening 65
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:evening 65
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:evening 65
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:evening 64
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:evening 65
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:morning 64
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:morning 64
# f_screen:phone_screen_rapids_countepisodeunlock:morning 70
# f_screen:phone_screen_rapids_sumdurationunlock:morning 70
# f_screen:phone_screen_rapids_maxdurationunlock:morning 70
# f_screen:phone_screen_rapids_mindurationunlock:morning 70
# f_screen:phone_screen_rapids_avgdurationunlock:morning 70
# f_screen:phone_screen_rapids_stddurationunlock:morning 66
# f_screen:phone_screen_rapids_firstuseafter00unlock:morning 70
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:morning 52
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:morning 67
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:morning 67
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:morning 67
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:morning 67
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:morning 67
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:morning 63
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:morning 67
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:night 65
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:night 65
# f_screen:phone_screen_rapids_countepisodeunlock:night 77
# f_screen:phone_screen_rapids_sumdurationunlock:night 77
# f_screen:phone_screen_rapids_maxdurationunlock:night 77
# f_screen:phone_screen_rapids_mindurationunlock:night 77
# f_screen:phone_screen_rapids_avgdurationunlock:night 77
# f_screen:phone_screen_rapids_stddurationunlock:night 76
# f_screen:phone_screen_rapids_firstuseafter00unlock:night 77
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:night 73
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night 73
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:night 73
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:night 73
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:night 73
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:night 71
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:night 73

# %% [markdown]
# ["f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night", "f_screen:phone_screen_rapids_sumdurationunlock:night", "f_screen:phone_screen_rapids_sumdurationunlock:allday"]

# %%
f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night

# %% [markdown]
# **PHQ4**
# * 0–2	    None
# * 3–5	    Mild
# * 6–8	    Moderate
# * 9–12	Severe

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Features to use
features_to_plot = {
    "bed": "f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday",
    "wake": "f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday"
}

# Merge features with PHQ4 scores
merged_df = pd.merge(
    pid_features_df[["date"] + list(features_to_plot.values())],
    pid_labels_df[["date", "phq4"]],
    on="date",
    how="left"
)

# Ensure datetime type for plotting and tick formatting
merged_df["date"] = pd.to_datetime(merged_df["date"])

# Convert minutes to hours after midnight
merged_df["first_bed_hr"] = merged_df[features_to_plot["bed"]] / 60
merged_df["first_wake_hr"] = merged_df[features_to_plot["wake"]] / 60

# Sort by date to ensure consistent time series
merged_df = merged_df.sort_values("date")

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot sleep features
ax1.plot(merged_df["date"], merged_df["first_bed_hr"], marker='o', label="First Bedtime (hr)")
ax1.plot(merged_df["date"], merged_df["first_wake_hr"], marker='o', label="First Wake Time (hr)")

ax1.set_xlabel("Date")
ax1.set_ylabel("Sleep Time (hours after midnight)")

# Restrict x-axis ticks to PHQ4 available dates
phq4_dates = merged_df.loc[merged_df["phq4"].notna(), "date"]
ax1.set_xticks(phq4_dates)
ax1.set_xticklabels(phq4_dates.dt.strftime('%Y-%m-%d'), rotation=45)

# PHQ4 scores on secondary axis
ax2 = ax1.twinx()
phq4_series = merged_df[["date", "phq4"]].dropna().sort_values("date")
ax2.plot(phq4_series["date"], phq4_series["phq4"], color='black', marker='s', linestyle='--', label='PHQ4 Score')
ax2.set_ylabel("PHQ4 Score")

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.title("First Bedtime / Wake Time and PHQ4 over Time")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Features list

# %% [markdown]
# ** Features to plot first **
#
# * f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:allday
# * f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:allday
# * f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:allday
# * f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday
# * f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:allday
# * f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday
# * f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:allday

# %%
for c in pid_features_df.columns:
    print(c)
# Out:
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:afternoon
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:afternoon
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:afternoon
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock:afternoon
# f_screen:phone_screen_rapids_mindurationunlock:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock:afternoon
# f_screen:phone_screen_rapids_stddurationunlock:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_mindurationunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_stddurationunlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_exercise:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_mindurationunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_stddurationunlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_living:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:afternoon
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:afternoon
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:afternoon
# f_steps:fitbit_steps_summary_rapids_maxsumsteps:afternoon
# f_steps:fitbit_steps_summary_rapids_minsumsteps:afternoon
# f_steps:fitbit_steps_summary_rapids_avgsumsteps:afternoon
# f_steps:fitbit_steps_summary_rapids_mediansumsteps:afternoon
# f_steps:fitbit_steps_summary_rapids_stdsumsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_sumsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_maxsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_minsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_avgsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_stdsteps:afternoon
# f_steps:fitbit_steps_intraday_rapids_countepisodesedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_sumdurationsedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_maxdurationsedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_mindurationsedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_avgdurationsedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_stddurationsedentarybout:afternoon
# f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:afternoon
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout:afternoon
# f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:afternoon
# f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:afternoon
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:afternoon
# f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:afternoon
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:allday
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:allday
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:allday
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:allday
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:allday
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:allday
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:allday
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:allday
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:allday
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:allday
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:allday
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:allday
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:allday
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:allday
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:allday
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:allday
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:allday
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:allday
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:allday
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:allday
# f_screen:phone_screen_rapids_countepisodeunlock:allday
# f_screen:phone_screen_rapids_sumdurationunlock:allday
# f_screen:phone_screen_rapids_maxdurationunlock:allday
# f_screen:phone_screen_rapids_mindurationunlock:allday
# f_screen:phone_screen_rapids_avgdurationunlock:allday
# f_screen:phone_screen_rapids_stddurationunlock:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock:allday
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_mindurationunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_stddurationunlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_exercise:allday
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:allday
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_living:allday
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living:allday
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_living:allday
# f_screen:phone_screen_rapids_mindurationunlock_locmap_living:allday
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:allday
# f_screen:phone_screen_rapids_stddurationunlock_locmap_living:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_living:allday
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:allday
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:allday
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:allday
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:allday
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:allday
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:allday
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:allday
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:allday
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:allday
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:allday
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:allday
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:allday
# f_steps:fitbit_steps_summary_rapids_maxsumsteps:allday
# f_steps:fitbit_steps_summary_rapids_minsumsteps:allday
# f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday
# f_steps:fitbit_steps_summary_rapids_mediansumsteps:allday
# f_steps:fitbit_steps_summary_rapids_stdsumsteps:allday
# f_steps:fitbit_steps_intraday_rapids_sumsteps:allday
# f_steps:fitbit_steps_intraday_rapids_maxsteps:allday
# f_steps:fitbit_steps_intraday_rapids_minsteps:allday
# f_steps:fitbit_steps_intraday_rapids_avgsteps:allday
# f_steps:fitbit_steps_intraday_rapids_stdsteps:allday
# f_steps:fitbit_steps_intraday_rapids_countepisodesedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_sumdurationsedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_maxdurationsedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_mindurationsedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_avgdurationsedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_stddurationsedentarybout:allday
# f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:allday
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout:allday
# f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:allday
# f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:allday
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday
# f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:allday
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:evening
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:evening
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:evening
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:evening
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:evening
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:evening
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:evening
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:evening
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:evening
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:evening
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:evening
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:evening
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:evening
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:evening
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:evening
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:evening
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:evening
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:evening
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:evening
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:evening
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:evening
# f_screen:phone_screen_rapids_countepisodeunlock:evening
# f_screen:phone_screen_rapids_sumdurationunlock:evening
# f_screen:phone_screen_rapids_maxdurationunlock:evening
# f_screen:phone_screen_rapids_mindurationunlock:evening
# f_screen:phone_screen_rapids_avgdurationunlock:evening
# f_screen:phone_screen_rapids_stddurationunlock:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock:evening
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_mindurationunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_stddurationunlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_exercise:evening
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:evening
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_living:evening
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living:evening
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_living:evening
# f_screen:phone_screen_rapids_mindurationunlock_locmap_living:evening
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:evening
# f_screen:phone_screen_rapids_stddurationunlock_locmap_living:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_living:evening
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:evening
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:evening
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:evening
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:evening
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:evening
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:evening
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:evening
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:evening
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:evening
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:evening
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:evening
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:evening
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:evening
# f_steps:fitbit_steps_summary_rapids_maxsumsteps:evening
# f_steps:fitbit_steps_summary_rapids_minsumsteps:evening
# f_steps:fitbit_steps_summary_rapids_avgsumsteps:evening
# f_steps:fitbit_steps_summary_rapids_mediansumsteps:evening
# f_steps:fitbit_steps_summary_rapids_stdsumsteps:evening
# f_steps:fitbit_steps_intraday_rapids_sumsteps:evening
# f_steps:fitbit_steps_intraday_rapids_maxsteps:evening
# f_steps:fitbit_steps_intraday_rapids_minsteps:evening
# f_steps:fitbit_steps_intraday_rapids_avgsteps:evening
# f_steps:fitbit_steps_intraday_rapids_stdsteps:evening
# f_steps:fitbit_steps_intraday_rapids_countepisodesedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_sumdurationsedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_maxdurationsedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_mindurationsedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_avgdurationsedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_stddurationsedentarybout:evening
# f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:evening
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout:evening
# f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:evening
# f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:evening
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:evening
# f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:evening
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:morning
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:morning
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:morning
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:morning
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:morning
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:morning
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:morning
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:morning
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:morning
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:morning
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:morning
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:morning
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:morning
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:morning
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:morning
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:morning
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:morning
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:morning
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:morning
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:morning
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:morning
# f_screen:phone_screen_rapids_countepisodeunlock:morning
# f_screen:phone_screen_rapids_sumdurationunlock:morning
# f_screen:phone_screen_rapids_maxdurationunlock:morning
# f_screen:phone_screen_rapids_mindurationunlock:morning
# f_screen:phone_screen_rapids_avgdurationunlock:morning
# f_screen:phone_screen_rapids_stddurationunlock:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock:morning
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_mindurationunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_stddurationunlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_exercise:morning
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:morning
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_living:morning
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living:morning
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_living:morning
# f_screen:phone_screen_rapids_mindurationunlock_locmap_living:morning
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:morning
# f_screen:phone_screen_rapids_stddurationunlock_locmap_living:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_living:morning
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:morning
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:morning
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:morning
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:morning
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:morning
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:morning
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:morning
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:morning
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:morning
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:morning
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:morning
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:morning
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:morning
# f_steps:fitbit_steps_summary_rapids_maxsumsteps:morning
# f_steps:fitbit_steps_summary_rapids_minsumsteps:morning
# f_steps:fitbit_steps_summary_rapids_avgsumsteps:morning
# f_steps:fitbit_steps_summary_rapids_mediansumsteps:morning
# f_steps:fitbit_steps_summary_rapids_stdsumsteps:morning
# f_steps:fitbit_steps_intraday_rapids_sumsteps:morning
# f_steps:fitbit_steps_intraday_rapids_maxsteps:morning
# f_steps:fitbit_steps_intraday_rapids_minsteps:morning
# f_steps:fitbit_steps_intraday_rapids_avgsteps:morning
# f_steps:fitbit_steps_intraday_rapids_stdsteps:morning
# f_steps:fitbit_steps_intraday_rapids_countepisodesedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_sumdurationsedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_maxdurationsedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_mindurationsedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_avgdurationsedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_stddurationsedentarybout:morning
# f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:morning
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout:morning
# f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:morning
# f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:morning
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:morning
# f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:morning
# f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:night
# f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:night
# f_slp:fitbit_sleep_summary_rapids_sumdurationawakemain:night
# f_slp:fitbit_sleep_summary_rapids_sumdurationtofallasleepmain:night
# f_slp:fitbit_sleep_summary_rapids_sumdurationinbedmain:night
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:night
# f_slp:fitbit_sleep_summary_rapids_avgdurationafterwakeupmain:night
# f_slp:fitbit_sleep_summary_rapids_avgdurationasleepmain:night
# f_slp:fitbit_sleep_summary_rapids_avgdurationawakemain:night
# f_slp:fitbit_sleep_summary_rapids_avgdurationtofallasleepmain:night
# f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:night
# f_slp:fitbit_sleep_summary_rapids_countepisodemain:night
# f_slp:fitbit_sleep_summary_rapids_firstbedtimemain:night
# f_slp:fitbit_sleep_summary_rapids_lastbedtimemain:night
# f_slp:fitbit_sleep_summary_rapids_firstwaketimemain:night
# f_slp:fitbit_sleep_summary_rapids_lastwaketimemain:night
# f_slp:fitbit_sleep_intraday_rapids_avgdurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_avgdurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_maxdurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_maxdurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_sumdurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_sumdurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_countepisodeasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_countepisodeawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_stddurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_stddurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_mindurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_mindurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_mediandurationasleepunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_mediandurationawakeunifiedmain:night
# f_slp:fitbit_sleep_intraday_rapids_ratiocountasleepunifiedwithinmain:night
# f_slp:fitbit_sleep_intraday_rapids_ratiocountawakeunifiedwithinmain:night
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationasleepunifiedwithinmain:night
# f_slp:fitbit_sleep_intraday_rapids_ratiodurationawakeunifiedwithinmain:night
# f_screen:phone_screen_rapids_countepisodeunlock:night
# f_screen:phone_screen_rapids_sumdurationunlock:night
# f_screen:phone_screen_rapids_maxdurationunlock:night
# f_screen:phone_screen_rapids_mindurationunlock:night
# f_screen:phone_screen_rapids_avgdurationunlock:night
# f_screen:phone_screen_rapids_stddurationunlock:night
# f_screen:phone_screen_rapids_firstuseafter00unlock:night
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_mindurationunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_stddurationunlock_locmap_exercise:night
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_exercise:night
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_greens:night
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_greens:night
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_greens:night
# f_screen:phone_screen_rapids_mindurationunlock_locmap_greens:night
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:night
# f_screen:phone_screen_rapids_stddurationunlock_locmap_greens:night
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_greens:night
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_living:night
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_living:night
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_living:night
# f_screen:phone_screen_rapids_mindurationunlock_locmap_living:night
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:night
# f_screen:phone_screen_rapids_stddurationunlock_locmap_living:night
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_living:night
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_study:night
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_study:night
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_study:night
# f_screen:phone_screen_rapids_mindurationunlock_locmap_study:night
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:night
# f_screen:phone_screen_rapids_stddurationunlock_locmap_study:night
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_study:night
# f_screen:phone_screen_rapids_countepisodeunlock_locmap_home:night
# f_screen:phone_screen_rapids_sumdurationunlock_locmap_home:night
# f_screen:phone_screen_rapids_maxdurationunlock_locmap_home:night
# f_screen:phone_screen_rapids_mindurationunlock_locmap_home:night
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:night
# f_screen:phone_screen_rapids_stddurationunlock_locmap_home:night
# f_screen:phone_screen_rapids_firstuseafter00unlock_locmap_home:night
# f_steps:fitbit_steps_summary_rapids_maxsumsteps:night
# f_steps:fitbit_steps_summary_rapids_minsumsteps:night
# f_steps:fitbit_steps_summary_rapids_avgsumsteps:night
# f_steps:fitbit_steps_summary_rapids_mediansumsteps:night
# f_steps:fitbit_steps_summary_rapids_stdsumsteps:night
# f_steps:fitbit_steps_intraday_rapids_sumsteps:night
# f_steps:fitbit_steps_intraday_rapids_maxsteps:night
# f_steps:fitbit_steps_intraday_rapids_minsteps:night
# f_steps:fitbit_steps_intraday_rapids_avgsteps:night
# f_steps:fitbit_steps_intraday_rapids_stdsteps:night
# f_steps:fitbit_steps_intraday_rapids_countepisodesedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_sumdurationsedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_maxdurationsedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_mindurationsedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_avgdurationsedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_stddurationsedentarybout:night
# f_steps:fitbit_steps_intraday_rapids_countepisodeactivebout:night
# f_steps:fitbit_steps_intraday_rapids_sumdurationactivebout:night
# f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:night
# f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:night
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:night
# f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:night
